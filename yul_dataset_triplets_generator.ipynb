# %%
import json

from datasets import load_dataset
import os
import pathlib
import re
import json
from subprocess import CalledProcessError

from utils import run_command
import yulopti
from jsonpath_ng import parse

# %%
dataset = load_dataset("KrzysztofFonal/yulcode")
# Out:
# Using the latest cached version of the dataset since KrzysztofFonal/yulcode couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at /Users/krzysztoffonal/.cache/huggingface/datasets/KrzysztofFonal___yulcode/default/0.0.0/0a253ef8257ef339cd54e0cb1fe50116dedd6131 (last modified on Tue Nov 12 22:12:51 2024).
# Loading dataset shards:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
dataset
temp_yul = open("temp.yul", "w")
print(dataset["train"][0]['source_code'], file=temp_yul)
print(dataset["train"][100]['source_code'])
temp_yul.close()

from utils import run_command
json.loads(run_command('./yuloptiml --json temp.yul'))
# Out:
# /// @use-src 0:"BSHIA.sol"
# object "BSHIA_1761" {
#     code {
#         /// @src 0:4185:17533  "contract BSHIA is Context, IERC20, Ownable {..."
#         mstore(64, memoryguard(128))
#         if callvalue() { revert_error_ca66f745a3ce8ff40e2ccaf1ad45db7774001b90d25810abd9040049be7bf4bb() }
#
#         constructor_BSHIA_1761()
#
#         let _1 := allocate_unbounded()
#         codecopy(_1, dataoffset("BSHIA_1761_deployed"), datasize("BSHIA_1761_deployed"))
#
#         return(_1, datasize("BSHIA_1761_deployed"))
#
#         function allocate_unbounded() -> memPtr {
#             memPtr := mload(64)
#         }
#
#         function revert_error_ca66f745a3ce8ff40e2ccaf1ad45db7774001b90d25810abd9040049be7bf4bb() {
#             revert(0, 0)
#         }
#
#         function cleanup_t_rational_0_by_1(value) -> cleaned {
#             cleaned := value
#         }
#
#         function cleanup_t_uint256(value) -> cleaned {
#             cleaned := value
#         }
#
#         function identity(value) -> ret {
#             ret := value
#         }
#
#         function convert_t_rational_0_by_1_to_t_uint256(value) -> converted {
#             converted := cleanup_t_uint256(identity(cleanup_t_rational_0_by_1(value)))
#         }
#
#         /// @src 0:4648:4690  "uint256 private constant MAX = ~uint256(0)"
#         function constant_MAX_425() -> ret {
#             /// @src 0:4688:4689  "0"
#             let expr_422 := 0x00
#             /// @src 0:4680:4690  "uint256(0)"
#             let expr_423 := convert_t_rational_0_by_1_to_t_uint256(expr_422)
#             /// @src 0:4679:4690  "~uint256(0)"
#             let expr_424 := cleanup_t_uint256(not(expr_423))
#             let _2 := expr_424
#
#             ret := _2
#         }
#
#         function cleanup_t_rational_1000000000000000_by_1(value) -> cleaned {
#             cleaned := value
#         }
#
#         function convert_t_rational_1000000000000000_by_1_to_t_uint256(value) -> converted {
#             converted := cleanup_t_uint256(identity(cleanup_t_rational_1000000000000000_by_1(value)))
#         }
#
#         /// @src 0:4697:4747  "uint256 private constant _tTotal = 1000000 * 10**9"
#         function constant__tTotal_432() -> ret {
#             /// @src 0:4732:4747  "1000000 * 10**9"
#             let expr_431 := 0x038d7ea4c68000
#             let _3 := convert_t_rational_1000000000000000_by_1_to_t_uint256(expr_431)
#
#             ret := _3
#         }
#
#         function panic_error_0x12() {
#             mstore(0, 35408467139433450592217433187231851964531694900788300625387963629091585785856)
#             mstore(4, 0x12)
#             revert(0, 0x24)
#         }
#
#         function mod_t_uint256(x, y) -> r {
#             x := cleanup_t_uint256(x)
#             y := cleanup_t_uint256(y)
#             if iszero(y) { panic_error_0x12() }
#             r := mod(x, y)
#         }
#
#         function panic_error_0x11() {
#             mstore(0, 35408467139433450592217433187231851964531694900788300625387963629091585785856)
#             mstore(4, 0x11)
#             revert(0, 0x24)
#         }
#
#         function checked_sub_t_uint256(x, y) -> diff {
#             x := cleanup_t_uint256(x)
#             y := cleanup_t_uint256(y)
#             diff := sub(x, y)
#
#             if gt(diff, x) { panic_error_0x11() }
#
#         }
#
#         function shift_left_0(value) -> newValue {
#             newValue :=
#
#             shl(0, value)
#
#         }
#
#         function update_byte_slice_32_shift_0(value, toInsert) -> result {
#             let mask := 0xffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffffff
#             toInsert := shift_left_0(toInsert)
#             value := and(value, not(mask))
#             result := or(value, and(toInsert, mask))
#         }
#
#         function convert_t_uint256_to_t_uint256(value) -> converted {
#             converted := cleanup_t_uint256(identity(cleanup_t_uint256(value)))
#         }
#
#         function prepare_store_t_uint256(value) -> ret {
#             ret := value
#         }
#
#         function update_storage_value_offset_0t_uint256_to_t_uint256(slot, value_0) {
#             let convertedValue_0 := convert_t_uint256_to_t_uint256(value_0)
#             sstore(slot, update_byte_slice_32_shift_0(sload(slot), prepare_store_t_uint256(convertedValue_0)))
#         }
#
#         function update_storage_value_offset_0t_rational_0_by_1_to_t_uint256(slot, value_0) {
#             let convertedValue_0 := convert_t_rational_0_by_1_to_t_uint256(value_0)
#             sstore(slot, update_byte_slice_32_shift_0(sload(slot), prepare_store_t_uint256(convertedValue_0)))
#         }
#
#         function cleanup_t_rational_20_by_1(value) -> cleaned {
#             cleaned := value
#         }
#
#         function convert_t_rational_20_by_1_to_t_uint256(value) -> converted {
#             converted := cleanup_t_uint256(identity(cleanup_t_rational_20_by_1(value)))
#         }
#
#         function update_storage_value_offset_0t_rational_20_by_1_to_t_uint256(slot, value_0) {
#             let convertedValue_0 := convert_t_rational_20_by_1_to_t_uint256(value_0)
#             sstore(slot, update_byte_slice_32_shift_0(sload(slot), prepare_store_t_uint256(convertedValue_0)))
#         }
#
#         function cleanup_t_rational_30_by_1(value) -> cleaned {
#             cleaned := value
#         }
#
#         function convert_t_rational_30_by_1_to_t_uint256(value) -> converted {
#             converted := cleanup_t_uint256(identity(cleanup_t_rational_30_by_1(value)))
#         }
#
#         function update_storage_value_offset_0t_rational_30_by_1_to_t_uint256(slot, value_0) {
#             let convertedValue_0 := convert_t_rational_30_by_1_to_t_uint256(value_0)
#             sstore(slot, update_byte_slice_32_shift_0(sload(slot), prepare_store_t_uint256(convertedValue_0)))
#         }
#
#         function shift_right_0_unsigned(value) -> newValue {
#             newValue :=
#
#             shr(0, value)
#
#         }
#
#         function cleanup_from_storage_t_uint256(value) -> cleaned {
#             cleaned := value
#         }
#
#         function extract_from_storage_value_offset_0t_uint256(slot_value) -> value {
#             value := cleanup_from_storage_t_uint256(shift_right_0_unsigned(slot_value))
#         }
#
#         function read_from_storage_split_offset_0_t_uint256(slot) -> value {
#             value := extract_from_storage_value_offset_0t_uint256(sload(slot))
#
#         }
#
#         function cleanup_t_uint160(value) -> cleaned {
#             cleaned := and(value, 0xffffffffffffffffffffffffffffffffffffffff)
#         }
#
#         function convert_t_uint160_to_t_uint160(value) -> converted {
#             converted := cleanup_t_uint160(identity(cleanup_t_uint160(value)))
#         }
#
#         function convert_t_uint160_to_t_address_payable(value) -> converted {
#             converted := convert_t_uint160_to_t_uint160(value)
#         }
#
#         function convert_t_address_to_t_address_payable(value) -> converted {
#             converted := convert_t_uint160_to_t_address_payable(value)
#         }
#
#         function update_byte_slice_20_shift_0(value, toInsert) -> result {
#             let mask := 0xffffffffffffffffffffffffffffffffffffffff
#             toInsert := shift_left_0(toInsert)
#             value := and(value, not(mask))
#             result := or(value, and(toInsert, mask))
#         }
#
#         function convert_t_address_payable_to_t_address_payable(value) -> converted {
#             converted := convert_t_uint160_to_t_address_payable(value)
#         }
#
#         function prepare_store_t_address_payable(value) -> ret {
#             ret := value
#         }
#
#         function update_storage_value_offset_0t_address_payable_to_t_address_payable(slot, value_0) {
#             let convertedValue_0 := convert_t_address_payable_to_t_address_payable(value_0)
#             sstore(slot, update_byte_slice_20_shift_0(sload(slot), prepare_store_t_address_payable(convertedValue_0)))
#         }
#
#         function shift_left_160(value) -> newValue {
#             newValue :=
#
#             shl(160, value)
#
#         }
#
#         function update_byte_slice_1_shift_20(value, toInsert) -> result {
#             let mask := 0xff0000000000000000000000000000000000000000
#             toInsert := shift_left_160(toInsert)
#             value := and(value, not(mask))
#             result := or(value, and(toInsert, mask))
#         }
#
#         function cleanup_t_bool(value) -> cleaned {
#             cleaned := iszero(iszero(value))
#         }
#
#         function convert_t_bool_to_t_bool(value) -> converted {
#             converted := cleanup_t_bool(value)
#         }
#
#         function prepare_store_t_bool(value) -> ret {
#             ret := value
#         }
#
#         function update_storage_value_offset_20t_bool_to_t_bool(slot, value_0) {
#             let convertedValue_0 := convert_t_bool_to_t_bool(value_0)
#             sstore(slot, update_byte_slice_1_shift_20(sload(slot), prepare_store_t_bool(convertedValue_0)))
#         }
#
#         function shift_left_168(value) -> newValue {
#             newValue :=
#
#             shl(168, value)
#
#         }
#
#         function update_byte_slice_1_shift_21(value, toInsert) -> result {
#             let mask := 0xff000000000000000000000000000000000000000000
#             toInsert := shift_left_168(toInsert)
#             value := and(value, not(mask))
#             result := or(value, and(toInsert, mask))
#         }
#
#         function update_storage_value_offset_21t_bool_to_t_bool(slot, value_0) {
#             let convertedValue_0 := convert_t_bool_to_t_bool(value_0)
#             sstore(slot, update_byte_slice_1_shift_21(sload(slot), prepare_store_t_bool(convertedValue_0)))
#         }
#
#         function shift_left_176(value) -> newValue {
#             newValue :=
#
#             shl(176, value)
#
#         }
#
#         function update_byte_slice_1_shift_22(value, toInsert) -> result {
#             let mask := 0xff00000000000000000000000000000000000000000000
#             toInsert := shift_left_176(toInsert)
#             value := and(value, not(mask))
#             result := or(value, and(toInsert, mask))
#         }
#
#         function update_storage_value_offset_22t_bool_to_t_bool(slot, value_0) {
#             let convertedValue_0 := convert_t_bool_to_t_bool(value_0)
#             sstore(slot, update_byte_slice_1_shift_22(sload(slot), prepare_store_t_bool(convertedValue_0)))
#         }
#
#         function cleanup_t_rational_20000000000000_by_1(value) -> cleaned {
#             cleaned := value
#         }
#
#         function convert_t_rational_20000000000000_by_1_to_t_uint256(value) -> converted {
#             converted := cleanup_t_uint256(identity(cleanup_t_rational_20000000000000_by_1(value)))
#         }
#
#         function update_storage_value_offset_0t_rational_20000000000000_by_1_to_t_uint256(slot, value_0) {
#             let convertedValue_0 := convert_t_rational_20000000000000_by_1_to_t_uint256(value_0)
#             sstore(slot, update_byte_slice_32_shift_0(sload(slot), prepare_store_t_uint256(convertedValue_0)))
#         }
#
#         function cleanup_t_rational_100000000000_by_1(value) -> cleaned {
#             cleaned := value
#         }
#
#         function convert_t_rational_100000000000_by_1_to_t_uint256(value) -> converted {
#             converted := cleanup_t_uint256(identity(cleanup_t_rational_100000000000_by_1(value)))
#         }
#
#         function update_storage_value_offset_0t_rational_100000000000_by_1_to_t_uint256(slot, value_0) {
#             let convertedValue_0 := convert_t_rational_100000000000_by_1_to_t_uint256(value_0)
#             sstore(slot, update_byte_slice_32_shift_0(sload(slot), prepare_store_t_uint256(convertedValue_0)))
#         }
#
#         function convert_t_uint160_to_t_address(value) -> converted {
#             converted := convert_t_uint160_to_t_uint160(value)
#         }
#
#         function convert_t_address_to_t_address(value) -> converted {
#             converted := convert_t_uint160_to_t_address(value)
#         }
#
#         function mapping_index_access_t_mapping$_t_address_$_t_uint256_$_of_t_address(slot , key) -> dataSlot {
#             mstore(0, convert_t_address_to_t_address(key))
#             mstore(0x20, slot)
#             dataSlot := keccak256(0, 0x40)
#         }
#
#         function convert_t_uint160_to_t_contract$_IUniswapV2Router02_$382(value) -> converted {
#             converted := convert_t_uint160_to_t_uint160(value)
#         }
#
#         function convert_t_address_to_t_contract$_IUniswapV2Router02_$382(value) -> converted {
#             converted := convert_t_uint160_to_t_contract$_IUniswapV2Router02_$382(value)
#         }
#
#         function convert_t_contract$_IUniswapV2Router02_$382_to_t_contract$_IUniswapV2Router02_$382(value) -> converted {
#             converted := convert_t_uint160_to_t_contract$_IUniswapV2Router02_$382(value)
#         }
#
#         function prepare_store_t_contract$_IUniswapV2Router02_$382(value) -> ret {
#             ret := value
#         }
#
#         function update_storage_value_offset_0t_contract$_IUniswapV2Router02_$382_to_t_contract$_IUniswapV2Router02_$382(slot, value_0) {
#             let convertedValue_0 := convert_t_contract$_IUniswapV2Router02_$382_to_t_contract$_IUniswapV2Router02_$382(value_0)
#             sstore(slot, update_byte_slice_20_shift_0(sload(slot), prepare_store_t_contract$_IUniswapV2Router02_$382(convertedValue_0)))
#         }
#
#         function convert_t_contract$_IUniswapV2Router02_$382_to_t_address(value) -> converted {
#             converted := convert_t_uint160_to_t_address(value)
#         }
#
#         function revert_error_0cc013b6b3b6beabea4e3a74a6d380f0df81852ca99887912475e1f66b2a2c20() {
#             revert(0, 0)
#         }
#
#         function round_up_to_mul_of_32(value) -> result {
#             result := and(add(value, 31), not(31))
#         }
#
#         function panic_error_0x41() {
#             mstore(0, 35408467139433450592217433187231851964531694900788300625387963629091585785856)
#             mstore(4, 0x41)
#             revert(0, 0x24)
#         }
#
#         function finalize_allocation(memPtr, size) {
#             let newFreePtr := add(memPtr, round_up_to_mul_of_32(size))
#             // protect against overflow
#             if or(gt(newFreePtr, 0xffffffffffffffff), lt(newFreePtr, memPtr)) { panic_error_0x41() }
#             mstore(64, newFreePtr)
#         }
#
#         function shift_left_224(value) -> newValue {
#             newValue :=
#
#             shl(224, value)
#
#         }
#
#         function revert_error_dbdddcbe895c83990c08b3492a0e83918d802a52331272ac6fdb6a7c4aea3b1b() {
#             revert(0, 0)
#         }
#
#         function revert_error_c1322bf8034eace5e0b5c7295db60986aa89aae5e0ea0873e4689e076861a5db() {
#             revert(0, 0)
#         }
#
#         function cleanup_t_address(value) -> cleaned {
#             cleaned := cleanup_t_uint160(value)
#         }
#
#         function validator_revert_t_address(value) {
#             if iszero(eq(value, cleanup_t_address(value))) { revert(0, 0) }
#         }
#
#         function abi_decode_t_address_fromMemory(offset, end) -> value {
#             value := mload(offset)
#             validator_revert_t_address(value)
#         }
#
#         function abi_decode_tuple_t_address_fromMemory(headStart, dataEnd) -> value0 {
#             if slt(sub(dataEnd, headStart), 32) { revert_error_dbdddcbe895c83990c08b3492a0e83918d802a52331272ac6fdb6a7c4aea3b1b() }
#
#             {
#
#                 let offset := 0
#
#                 value0 := abi_decode_t_address_fromMemory(add(headStart, offset), dataEnd)
#             }
#
#         }
#
#         function abi_encode_tuple__to__fromStack(headStart ) -> tail {
#             tail := add(headStart, 0)
#
#         }
#
#         function revert_forward_1() {
#             let pos := allocate_unbounded()
#             returndatacopy(pos, 0, returndatasize())
#             revert(pos, returndatasize())
#         }
#
#         function convert_t_uint160_to_t_contract$_IUniswapV2Factory_$336(value) -> converted {
#             converted := convert_t_uint160_to_t_uint160(value)
#         }
#
#         function convert_t_address_to_t_contract$_IUniswapV2Factory_$336(value) -> converted {
#             converted := convert_t_uint160_to_t_contract$_IUniswapV2Factory_$336(value)
#         }
#
#         function convert_t_contract$_IUniswapV2Factory_$336_to_t_address(value) -> converted {
#             converted := convert_t_uint160_to_t_address(value)
#         }
#
#         function convert_t_contract$_BSHIA_$1761_to_t_address(value) -> converted {
#             converted := convert_t_uint160_to_t_address(value)
#         }
#
#         function abi_encode_t_address_to_t_address_fromStack(value, pos) {
#             mstore(pos, cleanup_t_address(value))
#         }
#
#         function abi_encode_tuple_t_address_t_address__to_t_address_t_address__fromStack(headStart , value0, value1) -> tail {
#             tail := add(headStart, 64)
#
#             abi_encode_t_address_to_t_address_fromStack(value0,  add(headStart, 0))
#
#             abi_encode_t_address_to_t_address_fromStack(value1,  add(headStart, 32))
#
#         }
#
#         function prepare_store_t_address(value) -> ret {
#             ret := value
#         }
#
#         function update_storage_value_offset_0t_address_to_t_address(slot, value_0) {
#             let convertedValue_0 := convert_t_address_to_t_address(value_0)
#             sstore(slot, update_byte_slice_20_shift_0(sload(slot), prepare_store_t_address(convertedValue_0)))
#         }
#
#         function mapping_index_access_t_mapping$_t_address_$_t_bool_$_of_t_address(slot , key) -> dataSlot {
#             mstore(0, convert_t_address_to_t_address(key))
#             mstore(0x20, slot)
#             dataSlot := keccak256(0, 0x40)
#         }
#
#         function update_byte_slice_1_shift_0(value, toInsert) -> result {
#             let mask := 255
#             toInsert := shift_left_0(toInsert)
#             value := and(value, not(mask))
#             result := or(value, and(toInsert, mask))
#         }
#
#         function update_storage_value_offset_0t_bool_to_t_bool(slot, value_0) {
#             let convertedValue_0 := convert_t_bool_to_t_bool(value_0)
#             sstore(slot, update_byte_slice_1_shift_0(sload(slot), prepare_store_t_bool(convertedValue_0)))
#         }
#
#         function cleanup_from_storage_t_address_payable(value) -> cleaned {
#             cleaned := and(value, 0xffffffffffffffffffffffffffffffffffffffff)
#         }
#
#         function extract_from_storage_value_offset_0t_address_payable(slot_value) -> value {
#             value := cleanup_from_storage_t_address_payable(shift_right_0_unsigned(slot_value))
#         }
#
#         function read_from_storage_split_offset_0_t_address_payable(slot) -> value {
#             value := extract_from_storage_value_offset_0t_address_payable(sload(slot))
#
#         }
#
#         function convert_t_address_payable_to_t_address(value) -> converted {
#             converted := convert_t_uint160_to_t_address(value)
#         }
#
#         function mapping_index_access_t_mapping$_t_address_$_t_bool_$_of_t_address_payable(slot , key) -> dataSlot {
#             mstore(0, convert_t_address_payable_to_t_address(key))
#             mstore(0x20, slot)
#             dataSlot := keccak256(0, 0x40)
#         }
#
#         function convert_t_rational_0_by_1_to_t_uint160(value) -> converted {
#             converted := cleanup_t_uint160(identity(cleanup_t_rational_0_by_1(value)))
#         }
#
#         function convert_t_rational_0_by_1_to_t_address(value) -> converted {
#             converted := convert_t_rational_0_by_1_to_t_uint160(value)
#         }
#
#         function abi_encode_t_uint256_to_t_uint256_fromStack(value, pos) {
#             mstore(pos, cleanup_t_uint256(value))
#         }
#
#         function abi_encode_tuple_t_uint256__to_t_uint256__fromStack(headStart , value0) -> tail {
#             tail := add(headStart, 32)
#
#             abi_encode_t_uint256_to_t_uint256_fromStack(value0,  add(headStart, 0))
#
#         }
#
#         /// @ast-id 615
#         /// @src 0:6032:6666  "constructor() {..."
#         function constructor_BSHIA_1761() {
#
#             /// @src 0:6032:6666  "constructor() {..."
#             constructor_Ownable_180()
#             /// @src 0:4781:4784  "MAX"
#             let expr_434 := constant_MAX_425()
#             /// @src 0:4788:4791  "MAX"
#             let expr_435 := constant_MAX_425()
#             /// @src 0:4794:4801  "_tTotal"
#             let expr_436 := constant__tTotal_432()
#             /// @src 0:4788:4801  "MAX % _tTotal"
#             let expr_437 := mod_t_uint256(expr_435, expr_436)
#
#             /// @src 0:4787:4802  "(MAX % _tTotal)"
#             let expr_438 := expr_437
#             /// @src 0:4781:4802  "MAX - (MAX % _tTotal)"
#             let expr_439 := checked_sub_t_uint256(expr_434, expr_438)
#
#             /// @src 0:4780:4803  "(MAX - (MAX % _tTotal))"
#             let expr_440 := expr_439
#             update_storage_value_offset_0t_uint256_to_t_uint256(0x06, expr_440)
#             /// @src 0:4876:4877  "0"
#             let expr_445 := 0x00
#             update_storage_value_offset_0t_rational_0_by_1_to_t_uint256(0x08, expr_445)
#             /// @src 0:4915:4917  "20"
#             let expr_448 := 0x14
#             update_storage_value_offset_0t_rational_20_by_1_to_t_uint256(0x09, expr_448)
#             /// @src 0:4958:4959  "0"
#             let expr_451 := 0x00
#             update_storage_value_offset_0t_rational_0_by_1_to_t_uint256(0x0a, expr_451)
#             /// @src 0:4998:5000  "30"
#             let expr_454 := 0x1e
#             update_storage_value_offset_0t_rational_30_by_1_to_t_uint256(0x0b, expr_454)
#             /// @src 0:5057:5072  "_redisFeeOnSell"
#             let _4 := read_from_storage_split_offset_0_t_uint256(0x0a)
#             let expr_457 := _4
#             update_storage_value_offset_0t_uint256_to_t_uint256(0x0c, expr_457)
#             /// @src 0:5105:5118  "_taxFeeOnSell"
#             let _5 := read_from_storage_split_offset_0_t_uint256(0x0b)
#             let expr_460 := _5
#             update_storage_value_offset_0t_uint256_to_t_uint256(0x0d, expr_460)
#             /// @src 0:5163:5172  "_redisFee"
#             let _6 := read_from_storage_split_offset_0_t_uint256(0x0c)
#             let expr_463 := _6
#             update_storage_value_offset_0t_uint256_to_t_uint256(0x0e, expr_463)
#             /// @src 0:5213:5220  "_taxFee"
#             let _7 := read_from_storage_split_offset_0_t_uint256(0x0d)
#             let expr_466 := _7
#             update_storage_value_offset_0t_uint256_to_t_uint256(0x0f, expr_466)
#             /// @src 0:5371:5413  "0xb929F465760D6c6842b03fd75897Af2f93F3c80f"
#             let expr_479 := 0xb929f465760d6c6842b03fd75897af2f93f3c80f
#             /// @src 0:5363:5414  "payable(0xb929F465760D6c6842b03fd75897Af2f93F3c80f)"
#             let expr_480 := convert_t_address_to_t_address_payable(expr_479)
#             update_storage_value_offset_0t_address_payable_to_t_address_payable(0x12, expr_480)
#             /// @src 0:5473:5515  "0xb929F465760D6c6842b03fd75897Af2f93F3c80f"
#             let expr_485 := 0xb929f465760d6c6842b03fd75897af2f93f3c80f
#             /// @src 0:5465:5516  "payable(0xb929F465760D6c6842b03fd75897Af2f93F3c80f)"
#             let expr_486 := convert_t_address_to_t_address_payable(expr_485)
#             update_storage_value_offset_0t_address_payable_to_t_address_payable(0x13, expr_486)
#             /// @src 0:5637:5641  "true"
#             let expr_494 := 0x01
#             update_storage_value_offset_20t_bool_to_t_bool(0x15, expr_494)
#             /// @src 0:5670:5675  "false"
#             let expr_497 := 0x00
#             update_storage_value_offset_21t_bool_to_t_bool(0x15, expr_497)
#             /// @src 0:5709:5713  "true"
#             let expr_500 := 0x01
#             update_storage_value_offset_22t_bool_to_t_bool(0x15, expr_500)
#             /// @src 0:5752:5765  "20000 * 10**9"
#             let expr_507 := 0x12309ce54000
#             update_storage_value_offset_0t_rational_20000000000000_by_1_to_t_uint256(0x16, expr_507)
#             /// @src 0:5804:5817  "20000 * 10**9"
#             let expr_514 := 0x12309ce54000
#             update_storage_value_offset_0t_rational_20000000000000_by_1_to_t_uint256(0x17, expr_514)
#             /// @src 0:5861:5872  "100 * 10**9"
#             let expr_521 := 0x174876e800
#             update_storage_value_offset_0t_rational_100000000000_by_1_to_t_uint256(0x18, expr_521)
#
#             /// @src 0:6083:6090  "_rTotal"
#             let _8 := read_from_storage_split_offset_0_t_uint256(0x06)
#             let expr_545 := _8
#             /// @src 0:6059:6066  "_rOwned"
#             let _9_slot := 0x02
#             let expr_541_slot := _9_slot
#             /// @src 0:6067:6079  "_msgSender()"
#             let expr_543 := fun__msgSender_10()
#             /// @src 0:6059:6080  "_rOwned[_msgSender()]"
#             let _10 := mapping_index_access_t_mapping$_t_address_$_t_uint256_$_of_t_address(expr_541_slot,expr_543)
#             /// @src 0:6059:6090  "_rOwned[_msgSender()] = _rTotal"
#             update_storage_value_offset_0t_uint256_to_t_uint256(_10, expr_545)
#             let expr_546 := expr_545
#             /// @src 0:6160:6202  "0x7a250d5630B4cF539739dF2C5dAcb4c659F2488D"
#             let expr_552 := 0x7a250d5630b4cf539739df2c5dacb4c659f2488d
#             /// @src 0:6141:6203  "IUniswapV2Router02(0x7a250d5630B4cF539739dF2C5dAcb4c659F2488D)"
#             let expr_553_address := convert_t_address_to_t_contract$_IUniswapV2Router02_$382(expr_552)
#             /// @src 0:6103:6203  "IUniswapV2Router02 _uniswapV2Router = IUniswapV2Router02(0x7a250d5630B4cF539739dF2C5dAcb4c659F2488D)"
#             let var__uniswapV2Router_550_address := expr_553_address
#             /// @src 0:6234:6250  "_uniswapV2Router"
#             let _11_address := var__uniswapV2Router_550_address
#             let expr_556_address := _11_address
#             /// @src 0:6216:6250  "uniswapV2Router = _uniswapV2Router"
#             update_storage_value_offset_0t_contract$_IUniswapV2Router02_$382_to_t_contract$_IUniswapV2Router02_$382(0x14, expr_556_address)
#             let expr_557_address := expr_556_address
#             /// @src 0:6295:6311  "_uniswapV2Router"
#             let _12_address := var__uniswapV2Router_550_address
#             let expr_561_address := _12_address
#             /// @src 0:6295:6319  "_uniswapV2Router.factory"
#             let expr_562_address := convert_t_contract$_IUniswapV2Router02_$382_to_t_address(expr_561_address)
#             let expr_562_functionSelector := 0xc45a0155
#             /// @src 0:6295:6321  "_uniswapV2Router.factory()"
#
#             // storage for arguments and returned data
#             let _13 := allocate_unbounded()
#             mstore(_13, shift_left_224(expr_562_functionSelector))
#             let _14 := abi_encode_tuple__to__fromStack(add(_13, 4) )
#
#             let _15 := staticcall(gas(), expr_562_address,  _13, sub(_14, _13), _13, 32)
#
#             if iszero(_15) { revert_forward_1() }
#
#             let expr_563
#             if _15 {
#
#                 let _16 := 32
#
#                 if gt(_16, returndatasize()) {
#                     _16 := returndatasize()
#                 }
#
#                 // update freeMemoryPointer according to dynamic return size
#                 finalize_allocation(_13, _16)
#
#                 // decode return parameters from external try-call into retVars
#                 expr_563 :=  abi_decode_tuple_t_address_fromMemory(_13, add(_13, _16))
#             }
#             /// @src 0:6277:6322  "IUniswapV2Factory(_uniswapV2Router.factory())"
#             let expr_564_address := convert_t_address_to_t_contract$_IUniswapV2Factory_$336(expr_563)
#             /// @src 0:6277:6347  "IUniswapV2Factory(_uniswapV2Router.factory())..."
#             let expr_565_address := convert_t_contract$_IUniswapV2Factory_$336_to_t_address(expr_564_address)
#             let expr_565_functionSelector := 0xc9c65396
#             /// @src 0:6356:6360  "this"
#             let expr_568_address := address()
#             /// @src 0:6348:6361  "address(this)"
#             let expr_569 := convert_t_contract$_BSHIA_$1761_to_t_address(expr_568_address)
#             /// @src 0:6363:6379  "_uniswapV2Router"
#             let _17_address := var__uniswapV2Router_550_address
#             let expr_570_address := _17_address
#             /// @src 0:6363:6384  "_uniswapV2Router.WETH"
#             let expr_571_address := convert_t_contract$_IUniswapV2Router02_$382_to_t_address(expr_570_address)
#             let expr_571_functionSelector := 0xad5c4648
#             /// @src 0:6363:6386  "_uniswapV2Router.WETH()"
#
#             // storage for arguments and returned data
#             let _18 := allocate_unbounded()
#             mstore(_18, shift_left_224(expr_571_functionSelector))
#             let _19 := abi_encode_tuple__to__fromStack(add(_18, 4) )
#
#             let _20 := staticcall(gas(), expr_571_address,  _18, sub(_19, _18), _18, 32)
#
#             if iszero(_20) { revert_forward_1() }
#
#             let expr_572
#             if _20 {
#
#                 let _21 := 32
#
#                 if gt(_21, returndatasize()) {
#                     _21 := returndatasize()
#                 }
#
#                 // update freeMemoryPointer according to dynamic return size
#                 finalize_allocation(_18, _21)
#
#                 // decode return parameters from external try-call into retVars
#                 expr_572 :=  abi_decode_tuple_t_address_fromMemory(_18, add(_18, _21))
#             }
#             /// @src 0:6277:6387  "IUniswapV2Factory(_uniswapV2Router.factory())..."
#
#             // storage for arguments and returned data
#             let _22 := allocate_unbounded()
#             mstore(_22, shift_left_224(expr_565_functionSelector))
#             let _23 := abi_encode_tuple_t_address_t_address__to_t_address_t_address__fromStack(add(_22, 4) , expr_569, expr_572)
#
#             let _24 := call(gas(), expr_565_address,  0,  _22, sub(_23, _22), _22, 32)
#
#             if iszero(_24) { revert_forward_1() }
#
#             let expr_573
#             if _24 {
#
#                 let _25 := 32
#
#                 if gt(_25, returndatasize()) {
#                     _25 := returndatasize()
#                 }
#
#                 // update freeMemoryPointer according to dynamic return size
#                 finalize_allocation(_22, _25)
#
#                 // decode return parameters from external try-call into retVars
#                 expr_573 :=  abi_decode_tuple_t_address_fromMemory(_22, add(_22, _25))
#             }
#             /// @src 0:6261:6387  "uniswapV2Pair = IUniswapV2Factory(_uniswapV2Router.factory())..."
#             update_storage_value_offset_0t_address_to_t_address(0x15, expr_573)
#             let expr_574 := expr_573
#             /// @src 0:6430:6434  "true"
#             let expr_580 := 0x01
#             /// @src 0:6400:6418  "_isExcludedFromFee"
#             let _26_slot := 0x05
#             let expr_576_slot := _26_slot
#             /// @src 0:6419:6426  "owner()"
#             let expr_578 := fun_owner_119()
#             /// @src 0:6400:6427  "_isExcludedFromFee[owner()]"
#             let _27 := mapping_index_access_t_mapping$_t_address_$_t_bool_$_of_t_address(expr_576_slot,expr_578)
#             /// @src 0:6400:6434  "_isExcludedFromFee[owner()] = true"
#             update_storage_value_offset_0t_bool_to_t_bool(_27, expr_580)
#             let expr_581 := expr_580
#             /// @src 0:6481:6485  "true"
#             let expr_589 := 0x01
#             /// @src 0:6445:6463  "_isExcludedFromFee"
#             let _28_slot := 0x05
#             let expr_583_slot := _28_slot
#             /// @src 0:6472:6476  "this"
#             let expr_586_address := address()
#             /// @src 0:6464:6477  "address(this)"
#             let expr_587 := convert_t_contract$_BSHIA_$1761_to_t_address(expr_586_address)
#             /// @src 0:6445:6478  "_isExcludedFromFee[address(this)]"
#             let _29 := mapping_index_access_t_mapping$_t_address_$_t_bool_$_of_t_address(expr_583_slot,expr_587)
#             /// @src 0:6445:6485  "_isExcludedFromFee[address(this)] = true"
#             update_storage_value_offset_0t_bool_to_t_bool(_29, expr_589)
#             let expr_590 := expr_589
#             /// @src 0:6538:6542  "true"
#             let expr_595 := 0x01
#             /// @src 0:6496:6514  "_isExcludedFromFee"
#             let _30_slot := 0x05
#             let expr_592_slot := _30_slot
#             /// @src 0:6515:6534  "_developmentAddress"
#             let _31 := read_from_storage_split_offset_0_t_address_payable(0x12)
#             let expr_593 := _31
#             /// @src 0:6496:6535  "_isExcludedFromFee[_developmentAddress]"
#             let _32 := mapping_index_access_t_mapping$_t_address_$_t_bool_$_of_t_address_payable(expr_592_slot,expr_593)
#             /// @src 0:6496:6542  "_isExcludedFromFee[_developmentAddress] = true"
#             update_storage_value_offset_0t_bool_to_t_bool(_32, expr_595)
#             let expr_596 := expr_595
#             /// @src 0:6593:6597  "true"
#             let expr_601 := 0x01
#             /// @src 0:6553:6571  "_isExcludedFromFee"
#             let _33_slot := 0x05
#             let expr_598_slot := _33_slot
#             /// @src 0:6572:6589  "_marketingAddress"
#             let _34 := read_from_storage_split_offset_0_t_address_payable(0x13)
#             let expr_599 := _34
#             /// @src 0:6553:6590  "_isExcludedFromFee[_marketingAddress]"
#             let _35 := mapping_index_access_t_mapping$_t_address_$_t_bool_$_of_t_address_payable(expr_598_slot,expr_599)
#             /// @src 0:6553:6597  "_isExcludedFromFee[_marketingAddress] = true"
#             update_storage_value_offset_0t_bool_to_t_bool(_35, expr_601)
#             let expr_602 := expr_601
#             /// @src 0:6632:6633  "0"
#             let expr_607 := 0x00
#             /// @src 0:6624:6634  "address(0)"
#             let expr_608 := convert_t_rational_0_by_1_to_t_address(expr_607)
#             /// @src 0:6636:6648  "_msgSender()"
#             let expr_610 := fun__msgSender_10()
#             /// @src 0:6650:6657  "_tTotal"
#             let expr_611 := constant__tTotal_432()
#             /// @src 0:6615:6658  "Transfer(address(0), _msgSender(), _tTotal)"
#             let _36 := 0xddf252ad1be2c89b69c2b068fc378daa952ba7f163c4a11628f55a4df523b3ef
#             let _37 := convert_t_address_to_t_address(expr_608)
#             let _38 := convert_t_address_to_t_address(expr_610)
#             {
#                 let _39 := allocate_unbounded()
#                 let _40 := abi_encode_tuple_t_uint256__to_t_uint256__fromStack(_39 , expr_611)
#                 log3(_39, sub(_40, _39) , _36, _37, _38)
#             }
#         }
#         /// @src 0:4185:17533  "contract BSHIA is Context, IERC20, Ownable {..."
#
#         /// @ast-id 111
#         /// @src 0:1297:1450  "constructor() {..."
#         function constructor_Ownable_180() {
#
#             /// @src 0:1297:1450  "constructor() {..."
#             constructor_IERC20_78()
#
#             /// @src 0:1342:1354  "_msgSender()"
#             let expr_96 := fun__msgSender_10()
#             /// @src 0:1322:1354  "address msgSender = _msgSender()"
#             let var_msgSender_94 := expr_96
#             /// @src 0:1374:1383  "msgSender"
#             let _41 := var_msgSender_94
#             let expr_99 := _41
#             /// @src 0:1365:1383  "_owner = msgSender"
#             update_storage_value_offset_0t_address_to_t_address(0x00, expr_99)
#             let expr_100 := expr_99
#             /// @src 0:1428:1429  "0"
#             let expr_105 := 0x00
#             /// @src 0:1420:1430  "address(0)"
#             let expr_106 := convert_t_rational_0_by_1_to_t_address(expr_105)
#             /// @src 0:1432:1441  "msgSender"
#             let _42 := var_msgSender_94
#             let expr_107 := _42
#             /// @src 0:1399:1442  "OwnershipTransferred(address(0), msgSender)"
#             let _43 := 0x8be0079c531659141344cd1fd0a4f28419497f9722a3daafe3b4186f6b6457e0
#             let _44 := convert_t_address_to_t_address(expr_106)
#             let _45 := convert_t_address_to_t_address(expr_107)
#             {
#                 let _46 := allocate_unbounded()
#                 let _47 := abi_encode_tuple__to__fromStack(_46 )
#                 log3(_46, sub(_47, _46) , _43, _44, _45)
#             }
#         }
#         /// @src 0:4185:17533  "contract BSHIA is Context, IERC20, Ownable {..."
#
#         /// @src 0:322:1075  "interface IERC20 {..."
#         function constructor_IERC20_78() {
#
#             /// @src 0:322:1075  "interface IERC20 {..."
#             constructor_Context_11()
#
#         }
#         /// @src 0:4185:17533  "contract BSHIA is Context, IERC20, Ownable {..."
#
#         /// @src 0:184:318  "abstract contract Context {..."
#         function constructor_Context_11() {
#
#             /// @src 0:184:318  "abstract contract Context {..."
#
#         }
#         /// @src 0:4185:17533  "contract BSHIA is Context, IERC20, Ownable {..."
#
#         function zero_value_for_split_t_address() -> ret {
#             ret := 0
#         }
#
#         /// @ast-id 10
#         /// @src 0:217:315  "function _msgSender() internal view virtual returns (address) {..."
#         function fun__msgSender_10() -> var__4 {
#             /// @src 0:270:277  "address"
#             let zero_t_address_48 := zero_value_for_split_t_address()
#             var__4 := zero_t_address_48
#
#             /// @src 0:297:307  "msg.sender"
#             let expr_7 := caller()
#             /// @src 0:290:307  "return msg.sender"
#             var__4 := expr_7
#             leave
#
#         }
#         /// @src 0:4185:17533  "contract BSHIA is Context, IERC20, Ownable {..."
#
#         function cleanup_from_storage_t_address(value) -> cleaned {
#             cleaned := and(value, 0xffffffffffffffffffffffffffffffffffffffff)
#         }
#
#         function extract_from_storage_value_offset_0t_address(slot_value) -> value {
#             value := cleanup_from_storage_t_address(shift_right_0_unsigned(slot_value))
#         }
#
#         function read_from_storage_split_offset_0_t_address(slot) -> value {
#             value := extract_from_storage_value_offset_0t_address(sload(slot))
#
#         }
#
#         /// @ast-id 119
#         /// @src 0:1458:1537  "function owner() public view returns (address) {..."
#         function fun_owner_119() -> var__114 {
#             /// @src 0:1496:1503  "address"
#             let zero_t_address_49 := zero_value_for_split_t_address()
#             var__114 := zero_t_address_49
#
#             /// @src 0:1523:1529  "_owner"
#             let _50 := read_from_storage_split_offset_0_t_address(0x00)
#             let expr_116 := _50
#             /// @src 0:1516:1529  "return _owner"
#             var__114 := expr_116
#             leave
#
#         }
#         /// @src 0:4185:17533  "contract BSHIA is Context, IERC20, Ownable {..."
#
#     }
#     /// @use-src 0:"BSHIA.sol"
#     object "BSHIA_1761_deployed" {
#         code {
#             /// @src 0:4185:17533  "contract BSHIA is Context, IERC20, Ownable {..."
#             mstore(64, memoryguard(128))
#
#             if iszero(lt(calldatasize(), 4))
#             {
#                 let selector := shift_right_224_unsigned(calldataload(0))
#                 switch selector
#
#                 case 0x00b8cf2a
#                 {
#                     // blockBots(address[])
#
#                     external_fun_blockBots_1282()
#                 }
#
#                 case 0x06fdde03
#                 {
#                     // name()
#
#                     external_fun_name_623()
#                 }
#
#                 case 0x095ea7b3
#                 {
#                     // approve(address,uint256)
#
#                     external_fun_approve_720()
#                 }
#
#                 case 0x1694505e
#                 {
#                     // uniswapV2Router()
#
#                     external_fun_uniswapV2Router_490()
#                 }
#
#                 case 0x18160ddd
#                 {
#                     // totalSupply()
#
#                     external_fun_totalSupply_648()
#                 }
#
#                 case 0x23b872dd
#                 {
#                     // transferFrom(address,address,uint256)
#
#                     external_fun_transferFrom_757()
#                 }
#
#                 case 0x2fd689e3
#                 {
#                     // _swapTokensAtAmount()
#
#                     external_fun__swapTokensAtAmount_522()
#                 }
#
#                 case 0x313ce567
#                 {
#                     // decimals()
#
#                     external_fun_decimals_639()
#                 }
#
#                 case 0x49bd5a5e
#                 {
#                     // uniswapV2Pair()
#
#                     external_fun_uniswapV2Pair_492()
#                 }
#
#                 case 0x6b999053
#                 {
#                     // unblockBot(address)
#
#                     external_fun_unblockBot_1296()
#                 }
#
#                 case 0x6d8aa8f8
#                 {
#                     // toggleSwap(bool)
#
#                     external_fun_toggleSwap_1728()
#                 }
#
#                 case 0x6fc3eaec
#                 {
#                     // manualsend()
#
#                     external_fun_manualsend_1252()
#                 }
#
#                 case 0x70a08231
#                 {
#                     // balanceOf(address)
#
#                     external_fun_balanceOf_663()
#                 }
#
#                 case 0x715018a6
#                 {
#                     // renounceOwnership()
#
#                     external_fun_renounceOwnership_152()
#                 }
#
#                 case 0x751039fc
#                 {
#                     // removeLimits()
#
#                     external_fun_removeLimits_1310()
#                 }
#
#                 case 0x7d1db4a5
#                 {
#                     // _maxTxAmount()
#
#                     external_fun__maxTxAmount_508()
#                 }
#
#                 case 0x7f2feddc
#                 {
#                     // _buyMap(address)
#
#                     external_fun__buyMap_475()
#                 }
#
#                 case 0x8da5cb5b
#                 {
#                     // owner()
#
#                     external_fun_owner_119()
#                 }
#
#                 case 0x8f70ccf7
#                 {
#                     // setTrading(bool)
#
#                     external_fun_setTrading_1195()
#                 }
#
#                 case 0x8f9a55c0
#                 {
#                     // _maxWalletSize()
#
#                     external_fun__maxWalletSize_515()
#                 }
#
#                 case 0x95d89b41
#                 {
#                     // symbol()
#
#                     external_fun_symbol_631()
#                 }
#
#                 case 0x98a5c315
#                 {
#                     // setMinSwapTokensThreshold(uint256)
#
#                     external_fun_setMinSwapTokensThreshold_1716()
#                 }
#
#                 case 0xa2a957bb
#                 {
#                     // setFee(uint256,uint256,uint256,uint256)
#
#                     external_fun_setFee_1704()
#                 }
#
#                 case 0xa9059cbb
#                 {
#                     // transfer(address,uint256)
#
#                     external_fun_transfer_683()
#                 }
#
#                 case 0xbfd79284
#                 {
#                     // bots(address)
#
#                     external_fun_bots_471()
#                 }
#
#                 case 0xc3c8cd80
#                 {
#                     // manualswap()
#
#                     external_fun_manualswap_1224()
#                 }
#
#                 case 0xc492f046
#                 {
#                     // excludeMultipleAccountsFromFees(address[],bool)
#
#                     external_fun_excludeMultipleAccountsFromFees_1760()
#                 }
#
#                 case 0xdd62ed3e
#                 {
#                     // allowance(address,address)
#
#                     external_fun_allowance_700()
#                 }
#
#                 case 0xf2fde38b
#                 {
#                     // transferOwnership(address)
#
#                     external_fun_transferOwnership_179()
#                 }
#
#                 default {}
#             }
#             if iszero(calldatasize()) { fun__1464() stop() }
#             revert_error_d228b4ceac16d8e91d6dc7ca8d4a5394f524b2e550555324088cb23b86b87b98()
#
#             function shift_right_224_unsigned(value) -> newValue {
#                 newValue :=
#
#                 shr(224, value)
#
#             }
#
#             function allocate_unbounded() -> memPtr {
#                 memPtr := mload(64)
#             }
#
#             function revert_error_ca66f745a3ce8ff40e2ccaf1ad45db7774001b90d25810abd9040049be7bf4bb() {
#                 revert(0, 0)
#             }
#
#             function revert_error_dbdddcbe895c83990c08b3492a0e83918d802a52331272ac6fdb6a7c4aea3b1b() {
#                 revert(0, 0)
#             }
#
#             function revert_error_c1322bf8034eace5e0b5c7295db60986aa89aae5e0ea0873e4689e076861a5db() {
#                 revert(0, 0)
#             }
#
#             function revert_error_1b9f4a0a5773e33b91aa01db23bf8c55fce1411167c872835e7fa00a4f17d46d() {
#                 revert(0, 0)
#             }
#
#             function round_up_to_mul_of_32(value) -> result {
#                 result := and(add(value, 31), not(31))
#             }
#
#             function panic_error_0x41() {
#                 mstore(0, 35408467139433450592217433187231851964531694900788300625387963629091585785856)
#                 mstore(4, 0x41)
#                 revert(0, 0x24)
#             }
#
#             function finalize_allocation(memPtr, size) {
#                 let newFreePtr := add(memPtr, round_up_to_mul_of_32(size))
#                 // protect against overflow
#                 if or(gt(newFreePtr, 0xffffffffffffffff), lt(newFreePtr, memPtr)) { panic_error_0x41() }
#                 mstore(64, newFreePtr)
#             }
#
#             function allocate_memory(size) -> memPtr {
#                 memPtr := allocate_unbounded()
#                 finalize_allocation(memPtr, size)
#             }
#
#             function array_allocation_size_t_array$_t_address_$dyn_memory_ptr(length) -> size {
#                 // Make sure we can allocate memory without overflow
#                 if gt(length, 0xffffffffffffffff) { panic_error_0x41() }
#
#                 size := mul(length, 0x20)
#
#                 // add length slot
#                 size := add(size, 0x20)
#
#             }
#
#             function revert_error_81385d8c0b31fffe14be1da910c8bd3a80be4cfa248e04f42ec0faea3132a8ef() {
#                 revert(0, 0)
#             }
#
#             function cleanup_t_uint160(value) -> cleaned {
#                 cleaned := and(value, 0xffffffffffffffffffffffffffffffffffffffff)
#             }
#
#             function cleanup_t_address(value) -> cleaned {
#                 cleaned := cleanup_t_uint160(value)
#             }
#
#             function validator_revert_t_address(value) {
#                 if iszero(eq(value, cleanup_t_address(value))) { revert(0, 0) }
#             }
#
#             function abi_decode_t_address(offset, end) -> value {
#                 value := calldataload(offset)
#                 validator_revert_t_address(value)
#             }
#
#             // address[]
#             function abi_decode_available_length_t_array$_t_address_$dyn_memory_ptr(offset, length, end) -> array {
#                 array := allocate_memory(array_allocation_size_t_array$_t_address_$dyn_memory_ptr(length))
#                 let dst := array
#
#                 mstore(array, length)
#                 dst := add(array, 0x20)
#
#                 let srcEnd := add(offset, mul(length, 0x20))
#                 if gt(srcEnd, end) {
#                     revert_error_81385d8c0b31fffe14be1da910c8bd3a80be4cfa248e04f42ec0faea3132a8ef()
#                 }
#                 for { let src := offset } lt(src, srcEnd) { src := add(src, 0x20) }
#                 {
#
#                     let elementPos := src
#
#                     mstore(dst, abi_decode_t_address(elementPos, end))
#                     dst := add(dst, 0x20)
#                 }
#             }
#
#             // address[]
#             function abi_decode_t_array$_t_address_$dyn_memory_ptr(offset, end) -> array {
#                 if iszero(slt(add(offset, 0x1f), end)) { revert_error_1b9f4a0a5773e33b91aa01db23bf8c55fce1411167c872835e7fa00a4f17d46d() }
#                 let length := calldataload(offset)
#                 array := abi_decode_available_length_t_array$_t_address_$dyn_memory_ptr(add(offset, 0x20), length, end)
#             }
#
#             function abi_decode_tuple_t_array$_t_address_$dyn_memory_ptr(headStart, dataEnd) -> value0 {
#                 if slt(sub(dataEnd, headStart), 32) { revert_error_dbdddcbe895c83990c08b3492a0e83918d802a52331272ac6fdb6a7c4aea3b1b() }
#
#                 {
#
#                     let offset := calldataload(add(headStart, 0))
# ...
#             'nativeSrc': '123782:14:0',
#             'nodeType': 'YulTypedName',
#             'src': '19433:11:0',
#             'type': ''}]},
#          {'nativeSrc': '123874:26:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19445:5:0',
#           'value': {'name': 'var_owner_1025',
#            'nativeSrc': '123886:14:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19445:5:0'},
#           'variables': [{'name': '_126',
#             'nativeSrc': '123878:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19445:5:0',
#             'type': ''}]},
#          {'nativeSrc': '123917:21:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19445:5:0',
#           'value': {'name': '_126',
#            'nativeSrc': '123934:4:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19445:5:0'},
#           'variables': [{'name': 'expr_1053',
#             'nativeSrc': '123921:9:0',
#             'nodeType': 'YulTypedName',
#             'src': '19445:5:0',
#             'type': ''}]},
#          {'nativeSrc': '124016:131:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19433:18:0',
#           'value': {'arguments': [{'name': 'expr_1052_slot',
#              'nativeSrc': '124122:14:0',
#              'nodeType': 'YulIdentifier',
#              'src': '19433:18:0'},
#             {'name': 'expr_1053',
#              'nativeSrc': '124137:9:0',
#              'nodeType': 'YulIdentifier',
#              'src': '19433:18:0'}],
#            'functionName': {'name': 'mapping_index_access_t_mapping$_t_address_$_t_mapping$_t_address_$_t_uint256_$_$_of_t_address',
#             'nativeSrc': '124028:93:0',
#             'nodeType': 'YulIdentifier',
#             'src': '19433:18:0'},
#            'nativeSrc': '124028:119:0',
#            'nodeType': 'YulFunctionCall',
#            'src': '19433:18:0'},
#           'variables': [{'name': '_127',
#             'nativeSrc': '124020:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19433:18:0',
#             'type': ''}]},
#          {'nativeSrc': '124164:21:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19433:18:0',
#           'value': {'name': '_127',
#            'nativeSrc': '124181:4:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19433:18:0'},
#           'variables': [{'name': '_128_slot',
#             'nativeSrc': '124168:9:0',
#             'nodeType': 'YulTypedName',
#             'src': '19433:18:0',
#             'type': ''}]},
#          {'nativeSrc': '124202:31:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19433:18:0',
#           'value': {'name': '_128_slot',
#            'nativeSrc': '124224:9:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19433:18:0'},
#           'variables': [{'name': 'expr_1055_slot',
#             'nativeSrc': '124206:14:0',
#             'nodeType': 'YulTypedName',
#             'src': '19433:18:0',
#             'type': ''}]},
#          {'nativeSrc': '124300:28:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19452:7:0',
#           'value': {'name': 'var_spender_1027',
#            'nativeSrc': '124312:16:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19452:7:0'},
#           'variables': [{'name': '_129',
#             'nativeSrc': '124304:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19452:7:0',
#             'type': ''}]},
#          {'nativeSrc': '124345:21:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19452:7:0',
#           'value': {'name': '_129',
#            'nativeSrc': '124362:4:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19452:7:0'},
#           'variables': [{'name': 'expr_1054',
#             'nativeSrc': '124349:9:0',
#             'nodeType': 'YulTypedName',
#             'src': '19452:7:0',
#             'type': ''}]},
#          {'nativeSrc': '124453:106:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19433:27:0',
#           'value': {'arguments': [{'name': 'expr_1055_slot',
#              'nativeSrc': '124534:14:0',
#              'nodeType': 'YulIdentifier',
#              'src': '19433:27:0'},
#             {'name': 'expr_1054',
#              'nativeSrc': '124549:9:0',
#              'nodeType': 'YulIdentifier',
#              'src': '19433:27:0'}],
#            'functionName': {'name': 'mapping_index_access_t_mapping$_t_address_$_t_uint256_$_of_t_address',
#             'nativeSrc': '124465:68:0',
#             'nodeType': 'YulIdentifier',
#             'src': '19433:27:0'},
#            'nativeSrc': '124465:94:0',
#            'nodeType': 'YulFunctionCall',
#            'src': '19433:27:0'},
#           'variables': [{'name': '_130',
#             'nativeSrc': '124457:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19433:27:0',
#             'type': ''}]},
#          {'expression': {'arguments': [{'name': '_130',
#              'nativeSrc': '124707:4:0',
#              'nodeType': 'YulIdentifier',
#              'src': '19433:36:0'},
#             {'name': 'expr_1057',
#              'nativeSrc': '124713:9:0',
#              'nodeType': 'YulIdentifier',
#              'src': '19433:36:0'}],
#            'functionName': {'name': 'update_storage_value_offset_0t_uint256_to_t_uint256',
#             'nativeSrc': '124655:51:0',
#             'nodeType': 'YulIdentifier',
#             'src': '19433:36:0'},
#            'nativeSrc': '124655:68:0',
#            'nodeType': 'YulFunctionCall',
#            'src': '19433:36:0'},
#           'nativeSrc': '124655:68:0',
#           'nodeType': 'YulExpressionStatement',
#           'src': '19433:36:0'},
#          {'nativeSrc': '124740:26:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19433:36:0',
#           'value': {'name': 'expr_1057',
#            'nativeSrc': '124757:9:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19433:36:0'},
#           'variables': [{'name': 'expr_1058',
#             'nativeSrc': '124744:9:0',
#             'nodeType': 'YulTypedName',
#             'src': '19433:36:0',
#             'type': ''}]},
#          {'nativeSrc': '124831:26:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19494:5:0',
#           'value': {'name': 'var_owner_1025',
#            'nativeSrc': '124843:14:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19494:5:0'},
#           'variables': [{'name': '_131',
#             'nativeSrc': '124835:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19494:5:0',
#             'type': ''}]},
#          {'nativeSrc': '124874:21:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19494:5:0',
#           'value': {'name': '_131',
#            'nativeSrc': '124891:4:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19494:5:0'},
#           'variables': [{'name': 'expr_1061',
#             'nativeSrc': '124878:9:0',
#             'nodeType': 'YulTypedName',
#             'src': '19494:5:0',
#             'type': ''}]},
#          {'nativeSrc': '124962:28:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19501:7:0',
#           'value': {'name': 'var_spender_1027',
#            'nativeSrc': '124974:16:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19501:7:0'},
#           'variables': [{'name': '_132',
#             'nativeSrc': '124966:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19501:7:0',
#             'type': ''}]},
#          {'nativeSrc': '125007:21:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19501:7:0',
#           'value': {'name': '_132',
#            'nativeSrc': '125024:4:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19501:7:0'},
#           'variables': [{'name': 'expr_1062',
#             'nativeSrc': '125011:9:0',
#             'nodeType': 'YulTypedName',
#             'src': '19501:7:0',
#             'type': ''}]},
#          {'nativeSrc': '125094:27:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19510:6:0',
#           'value': {'name': 'var_amount_1029',
#            'nativeSrc': '125106:15:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19510:6:0'},
#           'variables': [{'name': '_133',
#             'nativeSrc': '125098:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19510:6:0',
#             'type': ''}]},
#          {'nativeSrc': '125138:21:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19510:6:0',
#           'value': {'name': '_133',
#            'nativeSrc': '125155:4:0',
#            'nodeType': 'YulIdentifier',
#            'src': '19510:6:0'},
#           'variables': [{'name': 'expr_1063',
#             'nativeSrc': '125142:9:0',
#             'nodeType': 'YulTypedName',
#             'src': '19510:6:0',
#             'type': ''}]},
#          {'nativeSrc': '125251:78:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19485:32:0',
#           'value': {'kind': 'number',
#            'nativeSrc': '125263:66:0',
#            'nodeType': 'YulLiteral',
#            'src': '19485:32:0',
#            'type': '',
#            'value': '0x8c5be1e5ebec7d5bd14f71427d1e84f3dd0314c0f7b2291e5b200ac8c7c3b925'},
#           'variables': [{'name': '_134',
#             'nativeSrc': '125255:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19485:32:0',
#             'type': ''}]},
#          {'nativeSrc': '125346:53:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19485:32:0',
#           'value': {'arguments': [{'name': 'expr_1061',
#              'nativeSrc': '125389:9:0',
#              'nodeType': 'YulIdentifier',
#              'src': '19485:32:0'}],
#            'functionName': {'name': 'convert_t_address_to_t_address',
#             'nativeSrc': '125358:30:0',
#             'nodeType': 'YulIdentifier',
#             'src': '19485:32:0'},
#            'nativeSrc': '125358:41:0',
#            'nodeType': 'YulFunctionCall',
#            'src': '19485:32:0'},
#           'variables': [{'name': '_135',
#             'nativeSrc': '125350:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19485:32:0',
#             'type': ''}]},
#          {'nativeSrc': '125416:53:0',
#           'nodeType': 'YulVariableDeclaration',
#           'src': '19485:32:0',
#           'value': {'arguments': [{'name': 'expr_1062',
#              'nativeSrc': '125459:9:0',
#              'nodeType': 'YulIdentifier',
#              'src': '19485:32:0'}],
#            'functionName': {'name': 'convert_t_address_to_t_address',
#             'nativeSrc': '125428:30:0',
#             'nodeType': 'YulIdentifier',
#             'src': '19485:32:0'},
#            'nativeSrc': '125428:41:0',
#            'nodeType': 'YulFunctionCall',
#            'src': '19485:32:0'},
#           'variables': [{'name': '_136',
#             'nativeSrc': '125420:4:0',
#             'nodeType': 'YulTypedName',
#             'src': '19485:32:0',
#             'type': ''}]},
#          {'nativeSrc': '125486:241:0',
#           'nodeType': 'YulBlock',
#           'src': '19485:32:0',
#           'statements': [{'nativeSrc': '125508:32:0',
#             'nodeType': 'YulVariableDeclaration',
#             'src': '19485:32:0',
#             'value': {'arguments': [],
#              'functionName': {'name': 'allocate_unbounded',
#               'nativeSrc': '125520:18:0',
#               'nodeType': 'YulIdentifier',
#               'src': '19485:32:0'},
#              'nativeSrc': '125520:20:0',
#              'nodeType': 'YulFunctionCall',
#              'src': '19485:32:0'},
#             'variables': [{'name': '_137',
#               'nativeSrc': '125512:4:0',
#               'nodeType': 'YulTypedName',
#               'src': '19485:32:0',
#               'type': ''}]},
#            {'nativeSrc': '125561:81:0',
#             'nodeType': 'YulVariableDeclaration',
#             'src': '19485:32:0',
#             'value': {'arguments': [{'name': '_137',
#                'nativeSrc': '125625:4:0',
#                'nodeType': 'YulIdentifier',
#                'src': '19485:32:0'},
#               {'name': 'expr_1063',
#                'nativeSrc': '125632:9:0',
#                'nodeType': 'YulIdentifier',
#                'src': '19485:32:0'}],
#              'functionName': {'name': 'abi_encode_tuple_t_uint256__to_t_uint256__fromStack',
#               'nativeSrc': '125573:51:0',
#               'nodeType': 'YulIdentifier',
#               'src': '19485:32:0'},
#              'nativeSrc': '125573:69:0',
#              'nodeType': 'YulFunctionCall',
#              'src': '19485:32:0'},
#             'variables': [{'name': '_138',
#               'nativeSrc': '125565:4:0',
#               'nodeType': 'YulTypedName',
#               'src': '19485:32:0',
#               'type': ''}]},
#            {'expression': {'arguments': [{'name': '_137',
#                'nativeSrc': '125668:4:0',
#                'nodeType': 'YulIdentifier',
#                'src': '19485:32:0'},
#               {'arguments': [{'name': '_138',
#                  'nativeSrc': '125678:4:0',
#                  'nodeType': 'YulIdentifier',
#                  'src': '19485:32:0'},
#                 {'name': '_137',
#                  'nativeSrc': '125684:4:0',
#                  'nodeType': 'YulIdentifier',
#                  'src': '19485:32:0'}],
#                'functionName': {'name': 'sub',
#                 'nativeSrc': '125674:3:0',
#                 'nodeType': 'YulIdentifier',
#                 'src': '19485:32:0'},
#                'nativeSrc': '125674:15:0',
#                'nodeType': 'YulFunctionCall',
#                'src': '19485:32:0'},
#               {'name': '_134',
#                'nativeSrc': '125692:4:0',
#                'nodeType': 'YulIdentifier',
#                'src': '19485:32:0'},
#               {'name': '_135',
#                'nativeSrc': '125698:4:0',
#                'nodeType': 'YulIdentifier',
#                'src': '19485:32:0'},
#               {'name': '_136',
#                'nativeSrc': '125704:4:0',
#                'nodeType': 'YulIdentifier',
#                'src': '19485:32:0'}],
#              'functionName': {'name': 'log3',
#               'nativeSrc': '125663:4:0',
#               'nodeType': 'YulIdentifier',
#               'src': '19485:32:0'},
#              'nativeSrc': '125663:46:0',
#              'nodeType': 'YulFunctionCall',
#              'src': '19485:32:0'},
#             'nativeSrc': '125663:46:0',
#             'nodeType': 'YulExpressionStatement',
#             'src': '19485:32:0'}]}]},
#        'name': 'fun__approve_1067',
#        'nativeSrc': '121952:3789:0',
#        'nodeType': 'YulFunctionDefinition',
#        'parameters': [{'name': 'var_owner_1025',
#          'nativeSrc': '121979:14:0',
#          'nodeType': 'YulTypedName',
#          'src': '19143:382:0',
#          'type': ''},
#         {'name': 'var_spender_1027',
#          'nativeSrc': '121995:16:0',
#          'nodeType': 'YulTypedName',
#          'src': '19143:382:0',
#          'type': ''},
#         {'name': 'var_amount_1029',
#          'nativeSrc': '122013:15:0',
#          'nodeType': 'YulTypedName',
#          'src': '19143:382:0',
#          'type': ''}],
#        'src': '19143:382:0'},
#       {'body': {'nativeSrc': '126033:16:0',
#         'nodeType': 'YulBlock',
#         'src': '19639:125:0',
#         'statements': []},
#        'name': 'fun__beforeTokenTransfer_1087',
#        'nativeSrc': '125949:100:0',
#        'nodeType': 'YulFunctionDefinition',
#        'parameters': [{'name': 'var_from_1079',
#          'nativeSrc': '125988:13:0',
#          'nodeType': 'YulTypedName',
#          'src': '19639:125:0',
#          'type': ''},
#         {'name': 'var_to_1081',
#          'nativeSrc': '126003:11:0',
#          'nodeType': 'YulTypedName',
#          'src': '19639:125:0',
#          'type': ''},
#         {'name': 'var_amount_1083',
#          'nativeSrc': '126016:15:0',
#          'nodeType': 'YulTypedName',
#          'src': '19639:125:0',
#          'type': ''}],
#        'src': '19639:125:0'}]},
#     'nodeType': 'YulCode'},
#    'name': 'EtherFlame_1088_deployed',
#    'nodeType': 'YulObject',
#    'subObjects': [{'nodeType': 'YulData',
#      'value': 'a26469706673582212207d46dafbd3347b10504f9e48a1b29007e5ecefb998ac0a1d6b8d8fb661b69abb64736f6c63430008130033'}]}]}

# %%
EVM_OPCODES = {
    'stop': 'voidTy',
    'add': 'numberTy', 
    'mul': 'numberTy', 
    'div': 'numberTy',
    'sdiv': 'numberTy',
    'mod': 'numberTy',
    'smod': 'numberTy',
    'exp': 'numberTy',
    'not': 'booleanTy',
    'lt': 'booleanTy',
    'gt': 'booleanTy',
    'slt': 'booleanTy',
    'sgt': 'booleanTy',
    'eq': 'booleanTy',
    'iszero': 'booleanTy',
    'and': 'booleanTy',
    'or': 'booleanTy',
    'xor': 'booleanTy',
    'byte': 'numberTy',
    'shl': 'numberTy',
    'shr': 'numberTy',
    'sar': 'numberTy',
    'addmod': 'numberTy',
    'mulmod': 'numberTy',
    'signextend': 'numberTy',
    'keccak256': 'numberTy',
    'pop': 'voidTy',
    'mload': 'numberTy',
    'mstore': 'voidTy',
    'mstore8': 'voidTy',
    'sload': 'numberTy',
    'sstore': 'voidTy',
    'tload': 'numberTy',
    'tstore': 'voidTy',
    'msize': 'numberTy',
    'gas': 'numberTy',
    'address': 'addressTy',
    'balance': 'numberTy',
    'selfbalance': 'numberTy',
    'caller': 'addressTy',
    'callvalue': 'numberTy',
    'calldataload': 'numberTy',
    'calldatasize': 'numberTy',
    'calldatacopy': 'voidTy',
    'codesize': 'numberTy',
    'codecopy': 'voidTy',
    'extcodesize': 'numberTy',
    'extcodecopy': 'voidTy',
    'returndatasize': 'numberTy',
    'returndatacopy': 'voidTy',
    'mcopy': 'voidTy',
    'extcodehash': 'numberTy',
    'create': 'addressTy',
    'create2': 'addressTy',
    'call': 'voidTy',
    'callcode': 'voidTy',
    'delegatecall': 'voidTy',
    'staticcall': 'voidTy',
    'return': 'voidTy',
    'revert': 'voidTy',
    'selfdestruct': 'voidTy',
    'invalid': 'voidTy',
    'log0': 'voidTy',
    'log1': 'voidTy',
    'log2': 'voidTy',
    'log3': 'voidTy',
    'log4': 'voidTy',
    'chainid': 'numberTy',
    'basefee': 'numberTy',
    'blobbasefee': 'numberTy',
    'origin': 'numberTy',
    'gasprice': 'numberTy',
    'blockhash': 'numberTy',
    'blobhash': 'numberTy',
    'coinbase': 'numberTy',
    'timestamp': 'numberTy',
    'number': 'numberTy',
    'difficulty': 'numberTy',
    'prevrandao': 'numberTy',
    'gaslimit': 'numberTy',
}

len(EVM_OPCODES)
# Out:
# 80

# %%
f = open("triplets.csv", "a")

def extract_arguments(ast):
    arguments = []
    for arg in ast:
        if arg["nodeType"] == "YulFunctionCall":
            arguments.append("function")
        elif arg["nodeType"] == "YulIdentifier":
            arguments.append("variable")
        elif arg["nodeType"] == "YulLiteral":
            arguments.append("constant")
        else:
            arguments.append("unknown")
    return "  ".join(arguments)

def extract_function_call(ast):
    opcode_name = ast["functionName"]["name"]
    opcode_type = EVM_OPCODES.get(ast["functionName"]["name"], None)
    if not opcode_type:
        opcode_type = "unknownTy"
        opcode_name = "functioncall"
    
    print(f"{opcode_name}  {opcode_type}  {extract_arguments(ast['arguments'])}", file=f)

# parse yul_json and print all nodes
def extract_triplets(ast):
    nodeType = ast["nodeType"]

    match nodeType:
        # YulObject is root node
        case "YulObject":
            extract_triplets(ast["code"])
        # YulCode is a container for code
        case "YulCode":
            extract_triplets(ast["block"])
        # YulBlock is a container for statements
        case "YulBlock":
            for statement in ast["statements"]:
                extract_triplets(statement)
        # YulFunctionCall is just a function call
        case "YulFunctionCall":
            extract_function_call(ast)
        # Statement is fundamental node inside block consisting of a few other possible node types
        case "YulExpressionStatement":
            extract_triplets(ast["expression"])
            # if ast["expression"]["nodeType"] == "YulFunctionCall":
            #     extract_function_call(ast["expression"])
        # Below nodes are statements options
        case "YulVariableDeclaration":
            if ast["value"]:
                extract_triplets(ast["value"])
        case "YulAssignment":
            extract_triplets(ast["value"])
        case "YulFunctionDefinition":
            # print(ast["name"])
            extract_triplets(ast["body"])
        case "YulIf":
            print(f"if boolTy {extract_arguments([ast['condition']])}", file=f)
            extract_triplets(ast["body"])
        case "YulForLoop":
            print("forloop voidTy", file=f)
            extract_triplets(ast["pre"])
            extract_triplets(ast["condition"])
            extract_triplets(ast["post"])
            extract_triplets(ast["body"])
        case "YulSwitch":
            print(f"switch voidTy {extract_arguments([ast['expression']])}", file=f)
            for switch_case in ast["cases"]:
                extract_triplets(switch_case["body"])
        case "YulBreak":
            print("break voidTy", file=f)
        case "YulContinue":
            print("continue voidTy", file=f)
        case "YulLeave":
            print("leave voidTy", file=f)
        case "YulIdentifier":
            # do nothing
            pass
        case "YulLiteral":
            # do nothing
            pass
        case _:
            print(f"Unknown node type: {nodeType}")

# %%
# yul_code = dataset["train"][0]['source_code']
# yul_json=yulopti.to_json(yul_code)
# # print(yul_json)
# ast = json.loads(yul_json)
# extract_triplets(ast)
i = 0
for yul_code in dataset["train"]:
    if i > 5:
        break
    # print(" Contract name: ", yul_code["contract_name"])
    # print(yul_code['source_code'])
    yul_json=yulopti.to_json(yul_code['source_code'])
    #print(yul_json)
    ast = json.loads(yul_json)
    extract_triplets(ast)
    for sub_object in ast['subObjects']:
        if 'code' in sub_object:
            extract_triplets(sub_object['code'])
    i += 1
    if i % 1000 == 0:
        print(f"Processed {i} contracts")
        f.flush()
f.close()
